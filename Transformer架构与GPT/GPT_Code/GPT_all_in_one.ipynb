# %%
import os
import requests
import math
import tiktoken
import torch
import torch.nn as nn
from torch.nn import functional as F

# Hyperparameters
batch_size = 8  # How many batches per training step
context_length = 16  # Length of the token chunk each batch
d_model = 64  # The size of our model token embeddings
num_blocks = 8  # Number of transformer blocks
num_heads = 4  # Number of heads in Multi-head attention
learning_rate = 1e-3  # learning rate
dropout = 0.1  # Dropout rate
max_iters = 5000  # Total of training iterations
eval_interval = 50  # How often to evaluate
eval_iters = 20  # Number of iterations to average for evaluation

# macOS 下使用 
device = 'cpu'
#device = 'mps' if torch.backends.mps.is_available() else 'cpu'  # 运行设备，若 GPU 可用则使用 'mps'，否则使用 'cpu'
print(f"Using device: {device}")
# Windows / Linux 下使用 
#device = 'cuda' if torch.cuda.is_available() else 'cpu'  # 运行设备，若 GPU 可用则使用 'cuda'，否则使用 'cpu'

TORCH_SEED = 1337
torch.manual_seed(TORCH_SEED)

# Load training data
if not os.path.exists('./sales_textbook.txt'):
    url = 'https://huggingface.co/datasets/goendalf666/sales-textbook_for_convincing_and_selling/raw/main/sales_textbook.txt'
    with open('sales_textbook.txt', 'w') as f:
        f.write(requests.get(url).text)

with open('./sales_textbook.txt', 'r', encoding='utf-8') as f:
    text = f.read()


# Using TikToken (Same as GPT3) to tokenize the source text
encoding = tiktoken.get_encoding("cl100k_base")
tokenized_text = encoding.encode(text)
max_token_value = max(tokenized_text) + 1  # the maximum value of the tokenized numbers
tokenized_text = torch.tensor(tokenized_text, dtype=torch.long, device=device)  # put tokenized text into tensor

# Split train and validation
split_idx = int(len(tokenized_text) * 0.9)
train_data = tokenized_text[:split_idx]
val_data = tokenized_text[split_idx:]


# Define Feed Forward Network
class FeedForward(nn.Module):
    def __init__(self):
        super().__init__()
        self.d_model = d_model
        self.dropout = dropout
        self.ffn = nn.Sequential(
            nn.Linear(in_features=self.d_model, out_features=self.d_model * 4),
            nn.ReLU(),
            nn.Linear(in_features=self.d_model * 4, out_features=self.d_model),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.ffn(x)


# Define Scaled Dot Product Attention
class Attention(nn.Module):
    def __init__(self, head_size: int):
        super().__init__()
        self.d_model = d_model
        self.head_size = head_size
        self.context_length = context_length
        self.dropout = dropout

        self.key_layer = nn.Linear(in_features=self.d_model, out_features=self.head_size, bias=False)
        self.query_layer = nn.Linear(in_features=self.d_model, out_features=self.head_size, bias=False)
        self.value_layer = nn.Linear(in_features=self.d_model, out_features=self.head_size, bias=False)
        self.register_buffer('tril', torch.tril(
            torch.ones((self.context_length, self.context_length))))  # Lower triangular mask
        self.dropout_layer = nn.Dropout(self.dropout)

    def forward(self, x):
        B, T, C = x.shape  # Batch size, Time steps(current context_length), Channels(dimensions)
        assert T <= self.context_length
        assert C == self.d_model
        q = self.query_layer(x)
        k = self.key_layer(x)
        v = self.value_layer(x)

        # Scaled dot product attention: Q @ K^T / sqrt(d_k)
        weights = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
        # Apply masked attention
        weights = weights.masked_fill(self.tril[:T, :T] == 0, float('-inf'))
        weights = F.softmax(input=weights, dim=-1)
        weights = self.dropout_layer(weights)

        # Apply dot product attention: weights @ V
        out = weights @ v
        return out


class MultiHeadAttention(nn.Module):
    def __init__(self, head_size: int):
        super().__init__()
        self.num_heads = num_heads
        self.head_size = head_size
        self.d_model = d_model
        self.context_length = context_length
        self.dropout = dropout

        self.heads = nn.ModuleList([Attention(head_size=self.head_size) for _ in range(self.num_heads)])
        self.projection_layer = nn.Linear(in_features=self.d_model, out_features=self.d_model)
        self.dropout_layer = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.projection_layer(out)
        out = self.dropout_layer(out)
        return out


class TransformerBlock(nn.Module):

    def __init__(self, num_heads: int):
        super().__init__()
        self.d_model = d_model
        self.context_length = context_length
        self.head_size = d_model // num_heads  # head size should be divisible by d_model
        self.num_heads = num_heads
        self.dropout = dropout

        self.multi_head_attention_layer = MultiHeadAttention(head_size=self.head_size)
        self.feed_forward_layer = FeedForward()
        self.layer_norm_1 = nn.LayerNorm(normalized_shape=self.d_model)
        self.layer_norm_2 = nn.LayerNorm(normalized_shape=self.d_model)

    def forward(self, x):
        x = self.layer_norm_1(x + self.multi_head_attention_layer(x))
        x = self.layer_norm_2(x + self.feed_forward_layer(x))
        return x



class TransformerLanguageModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.d_model = d_model
        self.context_length = context_length
        self.num_heads = num_heads
        self.num_blocks = num_blocks
        self.dropout = dropout
        self.max_token_value = max_token_value
        # Set up token embedding look-up table
        self.token_embedding_lookup_table = nn.Embedding(num_embeddings=self.max_token_value + 1, embedding_dim=self.d_model)

        # Run all the transformer blocks
        # Different from original paper, here we add a final layer norm after all the blocks
        self.transformer_blocks = nn.Sequential(*(
                [TransformerBlock(num_heads=self.num_heads) for _ in range(self.num_blocks)] +
                [nn.LayerNorm(self.d_model)]
        ))
        self.language_model_out_linear_layer = nn.Linear(in_features=self.d_model, out_features=self.max_token_value)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        """
        # Set up position embedding look-up table
        # following the same approach as the original Transformer paper (Sine and Cosine functions)
        """
        position_encoding_lookup_table = torch.zeros(self.context_length, self.d_model)
        position = torch.arange(0, self.context_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, self.d_model, 2).float() * (-math.log(10000.0) / self.d_model))
        position_encoding_lookup_table[:, 0::2] = torch.sin(position * div_term)
        position_encoding_lookup_table[:, 1::2] = torch.cos(position * div_term)
        # change position_encoding_lookup_table from (context_length, d_model) to (T, d_model)
        position_embedding = position_encoding_lookup_table[:T, :].to(device)
        x = self.token_embedding_lookup_table(idx) + position_embedding
        x = self.transformer_blocks(x)
        # The "logits" are the output values of our model before applying softmax
        logits = self.language_model_out_linear_layer(x)

        if targets is not None:
            B, T, C = logits.shape
            logits_reshaped = logits.view(B * T, C)
            targets_reshaped = targets.view(B * T)
            loss = F.cross_entropy(input=logits_reshaped, target=targets_reshaped)
        else:
            loss = None
        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B,T) array of indices in the current context
        for _ in range(max_new_tokens):
            # Crop idx to the max size of our positional embeddings table
            idx_crop = idx[:, -self.context_length:]
            # Get predictions
            logits, loss = self(idx_crop)
            # Get the last time step from logits where the dimensions of the logits are (B,T,C)
            logits_last_timestep = logits[:, -1, :]
            # Apply softmax to get probabilities
            probs = F.softmax(input=logits_last_timestep, dim=-1)
            # Sample from the probabilities' distribution.
            idx_next = torch.multinomial(input=probs, num_samples=1)
            # Append the sampled indexes idx_next to idx
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

    def sample_top_k(self,logits, k=10):
        # 对 logits 进行 Top-k 采样
        top_logits, top_indices = torch.topk(logits, k, dim=-1)  # 选取前 k 个最高概率的 token
        probs = F.softmax(top_logits, dim=-1)  # 归一化为概率分布
        sampled_index = torch.multinomial(probs, 1)  # 按概率进行随机采样
        return top_indices.gather(-1, sampled_index)  # 取出对应 token

    def generate_top_k(self, idx, max_new_tokens, k=10):
        # 生成文本，使用 Top-k 采样
        for _ in range(max_new_tokens):
            idx_crop = idx[:, -self.context_length:]  # 只取最近的 context_length 个 token
            logits, _ = self(idx_crop)  # 获取预测 logits
            logits_last_timestep = logits[:, -1, :]  # 取出最后一个时间步的 logits

            # 使用 Top-k 采样代替 Argmax
            idx_next = self.sample_top_k(logits_last_timestep, k)  # 这里改成 self.sample_top_k()
            idx = torch.cat((idx, idx_next), dim=1)
        return idx



# Initialize the model
model = TransformerLanguageModel()
model = model.to(device)


# Get input embedding batch
def get_batch(split: str):
    data = train_data if split == 'train' else val_data
    idxs = torch.randint(low=0, high=len(data) - context_length, size=(batch_size,))
    x = torch.stack([data[idx:idx + context_length] for idx in idxs]).to(device)
    y = torch.stack([data[idx + 1:idx + context_length + 1] for idx in idxs]).to(device)
    return x, y


# Calculate loss
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'valid']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            x_batch, y_batch = get_batch(split)
            logits, loss = model(x_batch, y_batch)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out


# Use AdamW optimizer
optimizer = torch.optim.AdamW(params=model.parameters(), lr=learning_rate)
tracked_losses = list()
for step in range(max_iters):
    if step % eval_iters == 0 or step == max_iters - 1:
        losses = estimate_loss()
        tracked_losses.append(losses)
        print('Step:', step, 'Training Loss:', round(losses['train'].item(), 3), 'Validation Loss:',
              round(losses['valid'].item(), 3))

    xb, yb = get_batch('train')
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# Save the model state dictionary
torch.save(model.state_dict(), 'model-ckpt.pt')

# Generate
model.eval()
start = 'The salesperson'
start_ids = encoding.encode(start)
x = (torch.tensor(start_ids, dtype=torch.long, device=device)[None, ...])
y = model.generate(x, max_new_tokens=100)
print('---------------')
print(encoding.decode(y[0].tolist()))
print('---------------')
# Out:
# Using device: cpu
# Step: 0 Training Loss: 11.679 Validation Loss: 11.702
# Step: 20 Training Loss: 10.19 Validation Loss: 10.263
# Step: 40 Training Loss: 8.537 Validation Loss: 8.723
# Step: 60 Training Loss: 7.013 Validation Loss: 7.338
# Step: 80 Training Loss: 6.574 Validation Loss: 6.973
# Step: 100 Training Loss: 6.178 Validation Loss: 6.958
# Step: 120 Training Loss: 6.289 Validation Loss: 6.8
# Step: 140 Training Loss: 6.14 Validation Loss: 6.781
# Step: 160 Training Loss: 6.043 Validation Loss: 6.594
# Step: 180 Training Loss: 5.796 Validation Loss: 6.371
# Step: 200 Training Loss: 5.634 Validation Loss: 6.446
# Step: 220 Training Loss: 5.535 Validation Loss: 6.235
# Step: 240 Training Loss: 5.541 Validation Loss: 6.198
# Step: 260 Training Loss: 5.453 Validation Loss: 6.21
# Step: 280 Training Loss: 5.302 Validation Loss: 6.051
# Step: 300 Training Loss: 5.165 Validation Loss: 6.127
# Step: 320 Training Loss: 5.248 Validation Loss: 6.044
# Step: 340 Training Loss: 5.383 Validation Loss: 5.985
# Step: 360 Training Loss: 4.958 Validation Loss: 6.057
# Step: 380 Training Loss: 4.857 Validation Loss: 5.883
# Step: 400 Training Loss: 4.935 Validation Loss: 5.79
# Step: 420 Training Loss: 4.727 Validation Loss: 6.031
# Step: 440 Training Loss: 4.818 Validation Loss: 5.748
# Step: 460 Training Loss: 4.729 Validation Loss: 5.544
# Step: 480 Training Loss: 4.674 Validation Loss: 5.764
# Step: 500 Training Loss: 4.701 Validation Loss: 5.636
# Step: 520 Training Loss: 4.629 Validation Loss: 5.717
# Step: 540 Training Loss: 4.591 Validation Loss: 5.615
# Step: 560 Training Loss: 4.641 Validation Loss: 5.736
# Step: 580 Training Loss: 4.509 Validation Loss: 5.622
# Step: 600 Training Loss: 4.46 Validation Loss: 5.797
# Step: 620 Training Loss: 4.292 Validation Loss: 5.58
# Step: 640 Training Loss: 4.449 Validation Loss: 5.619
# Step: 660 Training Loss: 4.546 Validation Loss: 5.399
# Step: 680 Training Loss: 4.251 Validation Loss: 5.451
# Step: 700 Training Loss: 4.277 Validation Loss: 5.324
# Step: 720 Training Loss: 4.311 Validation Loss: 5.286
# Step: 740 Training Loss: 4.006 Validation Loss: 5.324
# Step: 760 Training Loss: 4.321 Validation Loss: 5.467
# Step: 780 Training Loss: 4.061 Validation Loss: 5.402
# Step: 800 Training Loss: 4.273 Validation Loss: 5.229
# Step: 820 Training Loss: 4.118 Validation Loss: 5.21
# Step: 840 Training Loss: 4.106 Validation Loss: 5.337
# Step: 860 Training Loss: 4.103 Validation Loss: 5.256
# Step: 880 Training Loss: 4.132 Validation Loss: 5.336
# Step: 900 Training Loss: 4.123 Validation Loss: 5.149
# Step: 920 Training Loss: 4.014 Validation Loss: 5.224
# Step: 940 Training Loss: 3.867 Validation Loss: 5.096
# Step: 960 Training Loss: 3.972 Validation Loss: 5.289
# Step: 980 Training Loss: 4.076 Validation Loss: 5.353
# Step: 1000 Training Loss: 3.92 Validation Loss: 5.051
# Step: 1020 Training Loss: 3.904 Validation Loss: 5.169
# Step: 1040 Training Loss: 3.994 Validation Loss: 5.195
# Step: 1060 Training Loss: 3.719 Validation Loss: 5.157
# Step: 1080 Training Loss: 3.736 Validation Loss: 5.209
# Step: 1100 Training Loss: 3.839 Validation Loss: 5.16
# Step: 1120 Training Loss: 3.848 Validation Loss: 5.198
# Step: 1140 Training Loss: 3.788 Validation Loss: 5.015
# Step: 1160 Training Loss: 3.913 Validation Loss: 4.929
# Step: 1180 Training Loss: 3.807 Validation Loss: 5.148
# Step: 1200 Training Loss: 3.733 Validation Loss: 5.348
# Step: 1220 Training Loss: 3.77 Validation Loss: 5.197
# Step: 1240 Training Loss: 3.64 Validation Loss: 5.134
# Step: 1260 Training Loss: 3.637 Validation Loss: 5.204
# Step: 1280 Training Loss: 3.755 Validation Loss: 5.142
# Step: 1300 Training Loss: 3.677 Validation Loss: 5.128
# Step: 1320 Training Loss: 3.716 Validation Loss: 5.244
# Step: 1340 Training Loss: 3.754 Validation Loss: 4.901
# Step: 1360 Training Loss: 3.669 Validation Loss: 4.945
# Step: 1380 Training Loss: 3.555 Validation Loss: 4.9
# Step: 1400 Training Loss: 3.592 Validation Loss: 4.972
# Step: 1420 Training Loss: 3.632 Validation Loss: 5.064
# Step: 1440 Training Loss: 3.51 Validation Loss: 4.884
# Step: 1460 Training Loss: 3.649 Validation Loss: 4.942
# Step: 1480 Training Loss: 3.596 Validation Loss: 5.057
# Step: 1500 Training Loss: 3.663 Validation Loss: 5.001
# Step: 1520 Training Loss: 3.596 Validation Loss: 5.023
# Step: 1540 Training Loss: 3.498 Validation Loss: 4.915
# Step: 1560 Training Loss: 3.502 Validation Loss: 4.895
# Step: 1580 Training Loss: 3.664 Validation Loss: 4.939
# Step: 1600 Training Loss: 3.477 Validation Loss: 4.992
# Step: 1620 Training Loss: 3.516 Validation Loss: 5.133
# Step: 1640 Training Loss: 3.5 Validation Loss: 5.065
# Step: 1660 Training Loss: 3.564 Validation Loss: 4.849
# Step: 1680 Training Loss: 3.395 Validation Loss: 5.159
# Step: 1700 Training Loss: 3.19 Validation Loss: 4.8
# Step: 1720 Training Loss: 3.335 Validation Loss: 5.068
# Step: 1740 Training Loss: 3.465 Validation Loss: 5.005
# Step: 1760 Training Loss: 3.501 Validation Loss: 4.992
# Step: 1780 Training Loss: 3.4 Validation Loss: 4.905
# Step: 1800 Training Loss: 3.318 Validation Loss: 5.085
# Step: 1820 Training Loss: 3.442 Validation Loss: 5.018
# Step: 1840 Training Loss: 3.416 Validation Loss: 4.962
# Step: 1860 Training Loss: 3.307 Validation Loss: 4.846
# Step: 1880 Training Loss: 3.454 Validation Loss: 5.111
# Step: 1900 Training Loss: 3.491 Validation Loss: 5.191
# Step: 1920 Training Loss: 3.407 Validation Loss: 4.944
# Step: 1940 Training Loss: 3.248 Validation Loss: 4.901
# Step: 1960 Training Loss: 3.357 Validation Loss: 5.165
# Step: 1980 Training Loss: 3.215 Validation Loss: 4.872
# Step: 2000 Training Loss: 3.283 Validation Loss: 4.927
# Step: 2020 Training Loss: 3.34 Validation Loss: 5.054
# Step: 2040 Training Loss: 3.222 Validation Loss: 4.925
# Step: 2060 Training Loss: 3.383 Validation Loss: 5.058
# Step: 2080 Training Loss: 3.381 Validation Loss: 4.791
# Step: 2100 Training Loss: 3.213 Validation Loss: 4.858
# Step: 2120 Training Loss: 3.222 Validation Loss: 4.861
# Step: 2140 Training Loss: 3.242 Validation Loss: 5.141
# Step: 2160 Training Loss: 3.247 Validation Loss: 5.008
# Step: 2180 Training Loss: 3.191 Validation Loss: 5.026
# Step: 2200 Training Loss: 3.129 Validation Loss: 5.068
# Step: 2220 Training Loss: 3.21 Validation Loss: 4.856
# Step: 2240 Training Loss: 3.242 Validation Loss: 4.985
# Step: 2260 Training Loss: 3.184 Validation Loss: 4.908
# Step: 2280 Training Loss: 3.006 Validation Loss: 4.856
# Step: 2300 Training Loss: 3.165 Validation Loss: 4.936
# Step: 2320 Training Loss: 3.142 Validation Loss: 4.923
# Step: 2340 Training Loss: 3.244 Validation Loss: 5.05
# Step: 2360 Training Loss: 3.187 Validation Loss: 4.815
# Step: 2380 Training Loss: 3.245 Validation Loss: 4.653
# Step: 2400 Training Loss: 3.005 Validation Loss: 4.915
# Step: 2420 Training Loss: 3.113 Validation Loss: 4.955
# Step: 2440 Training Loss: 2.994 Validation Loss: 4.817
# Step: 2460 Training Loss: 3.129 Validation Loss: 5.096
# Step: 2480 Training Loss: 3.0 Validation Loss: 5.081
# Step: 2500 Training Loss: 3.162 Validation Loss: 4.834
# Step: 2520 Training Loss: 3.137 Validation Loss: 4.946
# Step: 2540 Training Loss: 3.1 Validation Loss: 5.213
# Step: 2560 Training Loss: 3.086 Validation Loss: 4.764
# Step: 2580 Training Loss: 2.844 Validation Loss: 4.851
# Step: 2600 Training Loss: 3.01 Validation Loss: 5.065
# Step: 2620 Training Loss: 3.082 Validation Loss: 5.007
# Step: 2640 Training Loss: 2.948 Validation Loss: 4.903
# Step: 2660 Training Loss: 3.01 Validation Loss: 4.949
# Step: 2680 Training Loss: 2.863 Validation Loss: 4.881
# Step: 2700 Training Loss: 2.952 Validation Loss: 4.792
# Step: 2720 Training Loss: 3.021 Validation Loss: 4.815
# Step: 2740 Training Loss: 2.953 Validation Loss: 4.949
# Step: 2760 Training Loss: 3.053 Validation Loss: 4.832
# Step: 2780 Training Loss: 2.913 Validation Loss: 5.094
# Step: 2800 Training Loss: 2.881 Validation Loss: 4.953
# Step: 2820 Training Loss: 2.951 Validation Loss: 4.983
# Step: 2840 Training Loss: 3.082 Validation Loss: 4.883
# Step: 2860 Training Loss: 2.955 Validation Loss: 4.945
# Step: 2880 Training Loss: 2.908 Validation Loss: 4.885
# Step: 2900 Training Loss: 2.871 Validation Loss: 4.972
# Step: 2920 Training Loss: 2.988 Validation Loss: 5.043
# Step: 2940 Training Loss: 2.947 Validation Loss: 4.804
# Step: 2960 Training Loss: 2.693 Validation Loss: 4.982
# Step: 2980 Training Loss: 2.908 Validation Loss: 5.026
# Step: 3000 Training Loss: 2.978 Validation Loss: 4.61
# Step: 3020 Training Loss: 2.922 Validation Loss: 4.905
# Step: 3040 Training Loss: 2.999 Validation Loss: 4.712
# Step: 3060 Training Loss: 2.824 Validation Loss: 4.781
# Step: 3080 Training Loss: 2.956 Validation Loss: 4.991
# Step: 3100 Training Loss: 2.903 Validation Loss: 4.743
# Step: 3120 Training Loss: 2.882 Validation Loss: 4.786
# Step: 3140 Training Loss: 2.82 Validation Loss: 4.869
# Step: 3160 Training Loss: 2.876 Validation Loss: 4.893
# Step: 3180 Training Loss: 2.902 Validation Loss: 4.843
# Step: 3200 Training Loss: 2.867 Validation Loss: 4.813
# Step: 3220 Training Loss: 2.686 Validation Loss: 4.879
# Step: 3240 Training Loss: 2.804 Validation Loss: 4.895
# Step: 3260 Training Loss: 2.826 Validation Loss: 4.762
# Step: 3280 Training Loss: 2.86 Validation Loss: 4.777
# Step: 3300 Training Loss: 2.902 Validation Loss: 4.839
# Step: 3320 Training Loss: 2.753 Validation Loss: 4.706
# Step: 3340 Training Loss: 2.879 Validation Loss: 4.699
# Step: 3360 Training Loss: 2.845 Validation Loss: 4.985
# Step: 3380 Training Loss: 2.856 Validation Loss: 4.777
# Step: 3400 Training Loss: 2.757 Validation Loss: 4.63
# Step: 3420 Training Loss: 2.85 Validation Loss: 4.971
# Step: 3440 Training Loss: 2.754 Validation Loss: 4.703
# Step: 3460 Training Loss: 2.852 Validation Loss: 4.838
# Step: 3480 Training Loss: 2.734 Validation Loss: 4.879
# Step: 3500 Training Loss: 2.854 Validation Loss: 4.692
# Step: 3520 Training Loss: 2.695 Validation Loss: 4.916
# Step: 3540 Training Loss: 2.735 Validation Loss: 4.676
# Step: 3560 Training Loss: 2.722 Validation Loss: 4.682
# Step: 3580 Training Loss: 2.737 Validation Loss: 4.652
# Step: 3600 Training Loss: 2.735 Validation Loss: 4.775
# Step: 3620 Training Loss: 2.788 Validation Loss: 4.62
# Step: 3640 Training Loss: 2.701 Validation Loss: 4.98
# Step: 3660 Training Loss: 2.693 Validation Loss: 4.839
# Step: 3680 Training Loss: 2.747 Validation Loss: 4.875
# Step: 3700 Training Loss: 2.744 Validation Loss: 4.883
# Step: 3720 Training Loss: 2.736 Validation Loss: 5.007
# Step: 3740 Training Loss: 2.783 Validation Loss: 4.827
# Step: 3760 Training Loss: 2.61 Validation Loss: 4.918
# Step: 3780 Training Loss: 2.787 Validation Loss: 4.859
# Step: 3800 Training Loss: 2.641 Validation Loss: 4.921
# Step: 3820 Training Loss: 2.645 Validation Loss: 4.775
# Step: 3840 Training Loss: 2.651 Validation Loss: 5.011
# Step: 3860 Training Loss: 2.637 Validation Loss: 4.651
# Step: 3880 Training Loss: 2.802 Validation Loss: 4.7
# Step: 3900 Training Loss: 2.768 Validation Loss: 4.908
# Step: 3920 Training Loss: 2.641 Validation Loss: 5.001
# Step: 3940 Training Loss: 2.63 Validation Loss: 4.943
# Step: 3960 Training Loss: 2.559 Validation Loss: 4.94
# Step: 3980 Training Loss: 2.703 Validation Loss: 4.935
# Step: 4000 Training Loss: 2.57 Validation Loss: 4.849
# Step: 4020 Training Loss: 2.694 Validation Loss: 4.645
# Step: 4040 Training Loss: 2.59 Validation Loss: 4.813
# Step: 4060 Training Loss: 2.613 Validation Loss: 4.613
# Step: 4080 Training Loss: 2.688 Validation Loss: 5.093
# Step: 4100 Training Loss: 2.701 Validation Loss: 4.942
# Step: 4120 Training Loss: 2.606 Validation Loss: 4.773
# Step: 4140 Training Loss: 2.566 Validation Loss: 4.775
# Step: 4160 Training Loss: 2.716 Validation Loss: 4.921
# Step: 4180 Training Loss: 2.634 Validation Loss: 5.064
# Step: 4200 Training Loss: 2.656 Validation Loss: 4.743
# Step: 4220 Training Loss: 2.593 Validation Loss: 4.882
# Step: 4240 Training Loss: 2.648 Validation Loss: 4.769
# Step: 4260 Training Loss: 2.646 Validation Loss: 4.83
# Step: 4280 Training Loss: 2.753 Validation Loss: 4.795
# Step: 4300 Training Loss: 2.619 Validation Loss: 4.831
# Step: 4320 Training Loss: 2.605 Validation Loss: 4.886
# Step: 4340 Training Loss: 2.644 Validation Loss: 4.639
# Step: 4360 Training Loss: 2.589 Validation Loss: 4.91
# Step: 4380 Training Loss: 2.58 Validation Loss: 4.771
# Step: 4400 Training Loss: 2.509 Validation Loss: 4.957
# Step: 4420 Training Loss: 2.639 Validation Loss: 5.009
# Step: 4440 Training Loss: 2.52 Validation Loss: 4.844
# Step: 4460 Training Loss: 2.646 Validation Loss: 4.94
# Step: 4480 Training Loss: 2.514 Validation Loss: 4.893
# Step: 4500 Training Loss: 2.526 Validation Loss: 5.049
# Step: 4520 Training Loss: 2.515 Validation Loss: 4.841
# Step: 4540 Training Loss: 2.505 Validation Loss: 4.981
# Step: 4560 Training Loss: 2.605 Validation Loss: 4.877
# Step: 4580 Training Loss: 2.522 Validation Loss: 4.791
# Step: 4600 Training Loss: 2.563 Validation Loss: 4.55
# Step: 4620 Training Loss: 2.477 Validation Loss: 4.681
# Step: 4640 Training Loss: 2.483 Validation Loss: 4.961
# Step: 4660 Training Loss: 2.584 Validation Loss: 4.958
# Step: 4680 Training Loss: 2.528 Validation Loss: 4.647
# Step: 4700 Training Loss: 2.379 Validation Loss: 4.889
# Step: 4720 Training Loss: 2.607 Validation Loss: 4.873
# Step: 4740 Training Loss: 2.641 Validation Loss: 4.847
# Step: 4760 Training Loss: 2.477 Validation Loss: 4.911
# Step: 4780 Training Loss: 2.414 Validation Loss: 4.711
# Step: 4800 Training Loss: 2.477 Validation Loss: 4.913
# Step: 4820 Training Loss: 2.433 Validation Loss: 5.035
# Step: 4840 Training Loss: 2.436 Validation Loss: 4.992
# Step: 4860 Training Loss: 2.449 Validation Loss: 4.894
# Step: 4880 Training Loss: 2.299 Validation Loss: 4.92
# Step: 4900 Training Loss: 2.464 Validation Loss: 4.684
# Step: 4920 Training Loss: 2.444 Validation Loss: 4.933
# Step: 4940 Training Loss: 2.592 Validation Loss: 4.875
# Step: 4960 Training Loss: 2.342 Validation Loss: 5.353
# Step: 4980 Training Loss: 2.432 Validation Loss: 4.868
# Step: 4999 Training Loss: 2.506 Validation Loss: 4.808
# ---------------
# The salesperson set the sales process but also positively of the closing their approach. While objections can also shows that they are actively listening to their specific needs can meet the underlying concerns and pain points of your clarity,. By asking open-ended questions, you encourage customers to craft thoughtful on your product or service.
# Anticipating objections related to timing or urgency requires active engagement. Keep yourself your customers towards closing positive first relationships with the sale and offers our customers.
# 2. Utilize the nature of By del to your customers
# ---------------

# %%
import matplotlib.pyplot as plt

train_losses = [t['train'] for t in tracked_losses]
val_losses = [t['valid'] for t in tracked_losses]
steps = list(range(0, len(tracked_losses) * eval_iters, eval_iters))

plt.figure(figsize=(10, 5))
plt.plot(steps, train_losses, label='Training Loss', marker='o')
plt.plot(steps, val_losses, label='Validation Loss', marker='s')
plt.xlabel("Training Steps")
plt.ylabel("Loss")
plt.title("Training & Validation Loss Over Time")
plt.legend()
plt.grid()
plt.show()
