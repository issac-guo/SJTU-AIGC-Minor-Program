# %% [markdown]
# # 上海交通大学 生成式人工智能AIGC微专业 微调与数据集构建
# # 实践1：使用LLaMA-Factory 进行微调
#
# 赵伟明 weiming.zhao@sjtu.edu.cn
#
# 2026年3月

# %% [markdown]
# ## 1. 安装 LLaMA-Factory

# %%
# 1. 使用 Gitee 镜像拉取 LLaMA-Factory
# !git clone --depth 1 https://gitee.com/hiyouga/LLaMA-Factory.git
# Out:
# Cloning into 'LLaMA-Factory'...
# fatal: failed to load library 'libcurl-4.dll'

# %%
# !pip uninstall -y vllm
# !pip install llamafactory[metrics] -U
# Out:
# WARNING: Skipping vllm as it is not installed.
# Collecting llamafactory[metrics]
#   Downloading llamafactory-0.9.4-py3-none-any.whl.metadata (73 kB)
# Collecting accelerate<=1.11.0,>=1.3.0 (from llamafactory[metrics])
#   Downloading accelerate-1.11.0-py3-none-any.whl.metadata (19 kB)
# Collecting av (from llamafactory[metrics])
#   Downloading av-16.1.0-cp311-cp311-win_amd64.whl.metadata (4.7 kB)
# Collecting datasets<=4.0.0,>=2.16.0 (from llamafactory[metrics])
#   Downloading datasets-4.0.0-py3-none-any.whl.metadata (19 kB)
# Collecting einops (from llamafactory[metrics])
#   Downloading einops-0.8.2-py3-none-any.whl.metadata (13 kB)
# Collecting fastapi (from llamafactory[metrics])
#   Downloading fastapi-0.135.1-py3-none-any.whl.metadata (30 kB)
# Collecting fire (from llamafactory[metrics])
#   Downloading fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting gradio<=5.50.0,>=4.38.0 (from llamafactory[metrics])
#   Downloading gradio-5.50.0-py3-none-any.whl.metadata (16 kB)
# Collecting hf-transfer (from llamafactory[metrics])
#   Downloading hf_transfer-0.1.9-cp38-abi3-win_amd64.whl.metadata (1.8 kB)
# Requirement already satisfied: matplotlib>=3.7.0 in E:\anaconda\envs\AIGC\Lib\site-packages (from llamafactory[metrics]) (3.10.8)
# Collecting modelscope (from llamafactory[metrics])
#   Downloading modelscope-1.34.0-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: numpy in E:\anaconda\envs\AIGC\Lib\site-packages (from llamafactory[metrics]) (2.4.2)
# Collecting omegaconf (from llamafactory[metrics])
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: packaging in E:\anaconda\envs\AIGC\Lib\site-packages (from llamafactory[metrics]) (25.0)
# Collecting pandas (from llamafactory[metrics])
#   Downloading pandas-3.0.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting peft<=0.17.1,>=0.14.0 (from llamafactory[metrics])
#   Downloading peft-0.17.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: protobuf in E:\anaconda\envs\AIGC\Lib\site-packages (from llamafactory[metrics]) (3.20.3)
# Collecting pydantic (from llamafactory[metrics])
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting pyyaml (from llamafactory[metrics])
#   Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# Collecting safetensors (from llamafactory[metrics])
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting scipy (from llamafactory[metrics])
#   Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting sentencepiece (from llamafactory[metrics])
#   Downloading sentencepiece-0.2.1-cp311-cp311-win_amd64.whl.metadata (10 kB)
# Collecting sse-starlette (from llamafactory[metrics])
#   Downloading sse_starlette-3.3.2-py3-none-any.whl.metadata (14 kB)
# Collecting tiktoken (from llamafactory[metrics])
#   Downloading tiktoken-0.12.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Collecting torch>=2.4.0 (from llamafactory[metrics])
#   Downloading torch-2.10.0-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Collecting torchaudio>=2.4.0 (from llamafactory[metrics])
#   Downloading torchaudio-2.10.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Collecting torchdata<=0.11.0,>=0.10.0 (from llamafactory[metrics])
#   Downloading torchdata-0.11.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting torchvision>=0.19.0 (from llamafactory[metrics])
#   Downloading torchvision-0.25.0-cp311-cp311-win_amd64.whl.metadata (5.4 kB)
# Collecting transformers!=4.52.0,!=4.57.0,<=4.57.1,>=4.51.0 (from llamafactory[metrics])
#   Downloading transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
# Collecting trl<=0.24.0,>=0.18.0 (from llamafactory[metrics])
#   Downloading trl-0.24.0-py3-none-any.whl.metadata (11 kB)
# Collecting tyro<0.9.0 (from llamafactory[metrics])
#   Downloading tyro-0.8.14-py3-none-any.whl.metadata (8.4 kB)
# Collecting uvicorn (from llamafactory[metrics])
#   Downloading uvicorn-0.41.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting jieba (from llamafactory[metrics])
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      ---------------------------------------- 0.0/19.2 MB ? eta -:--:--
#      - -------------------------------------- 0.5/19.2 MB 4.2 MB/s eta 0:00:05
#      ------ --------------------------------- 2.9/19.2 MB 9.9 MB/s eta 0:00:02
#      -------------- ------------------------- 6.8/19.2 MB 13.1 MB/s eta 0:00:01
#      --------------------- ----------------- 10.5/19.2 MB 14.5 MB/s eta 0:00:01
#      ----------------------------- --------- 14.7/19.2 MB 15.4 MB/s eta 0:00:01
#      ------------------------------------- - 18.4/19.2 MB 15.6 MB/s eta 0:00:01
#      ---------------------------------------- 19.2/19.2 MB 15.2 MB/s  0:00:01
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting nltk (from llamafactory[metrics])
#   Downloading nltk-3.9.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting rouge-chinese (from llamafactory[metrics])
#   Downloading rouge_chinese-1.0.3-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: psutil in E:\anaconda\envs\AIGC\Lib\site-packages (from accelerate<=1.11.0,>=1.3.0->llamafactory[metrics]) (7.2.2)
# Collecting huggingface_hub>=0.21.0 (from accelerate<=1.11.0,>=1.3.0->llamafactory[metrics])
#   Downloading huggingface_hub-1.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading filelock-3.25.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting pyarrow>=15.0.0 (from datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading pyarrow-23.0.1-cp311-cp311-win_amd64.whl.metadata (3.1 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting requests>=2.32.2 (from datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm>=4.66.3 (from datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Collecting xxhash (from datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading xxhash-3.6.0-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading aiohttp-3.13.3-cp311-cp311-win_amd64.whl.metadata (8.4 kB)
# Collecting aiofiles<25.0,>=22.0 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting anyio<5.0,>=3.0 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting brotli>=1.1.0 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading brotli-1.2.0-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Collecting ffmpy (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==1.14.0 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading gradio_client-1.14.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting httpx<1.0,>=0.24.1 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jinja2<4.0 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe<4.0,>=2.0 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading markupsafe-3.0.3-cp311-cp311-win_amd64.whl.metadata (2.8 kB)
# Collecting orjson~=3.0 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading orjson-3.11.7-cp311-cp311-win_amd64.whl.metadata (43 kB)
# Collecting pandas (from llamafactory[metrics])
#   Downloading pandas-2.3.3-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting pillow<12.0,>=8.0 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading pillow-11.3.0-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Collecting pydantic (from llamafactory[metrics])
#   Downloading pydantic-2.12.3-py3-none-any.whl.metadata (87 kB)
# Collecting pydub (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading python_multipart-0.0.22-py3-none-any.whl.metadata (1.8 kB)
# Collecting ruff>=0.9.3 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading ruff-0.15.5-py3-none-win_amd64.whl.metadata (27 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading starlette-0.52.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting typer<1.0,>=0.12 (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading typer-0.24.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions~=4.0 in E:\anaconda\envs\AIGC\Lib\site-packages (from gradio<=5.50.0,>=4.38.0->llamafactory[metrics]) (4.15.0)
# Collecting websockets<16.0,>=13.0 (from gradio-client==1.14.0->gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Collecting idna>=2.8 (from anyio<5.0,>=3.0->gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting typing-inspection>=0.4.2 (from fastapi->llamafactory[metrics])
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi->llamafactory[metrics])
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi (from httpx<1.0,>=0.24.1->gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1.0,>=0.24.1->gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting hf-xet<2.0.0,>=1.3.2 (from huggingface_hub>=0.21.0->accelerate<=1.11.0,>=1.3.0->llamafactory[metrics])
#   Downloading hf_xet-1.3.2-cp37-abi3-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in E:\anaconda\envs\AIGC\Lib\site-packages (from pandas->llamafactory[metrics]) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->llamafactory[metrics])
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->llamafactory[metrics])
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic->llamafactory[metrics])
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.4 (from pydantic->llamafactory[metrics])
#   Downloading pydantic_core-2.41.4-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Collecting urllib3>=1.25 (from torchdata<=0.11.0,>=0.10.0->llamafactory[metrics])
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting huggingface_hub>=0.21.0 (from accelerate<=1.11.0,>=1.3.0->llamafactory[metrics])
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Collecting regex!=2019.12.17 (from transformers!=4.52.0,!=4.57.0,<=4.57.1,>=4.51.0->llamafactory[metrics])
#   Downloading regex-2026.2.28-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers!=4.52.0,!=4.57.0,<=4.57.1,>=4.51.0->llamafactory[metrics])
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting click>=8.2.1 (from typer<1.0,>=0.12->gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=12.3.0 (from typer<1.0,>=0.12->gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading rich-14.3.3-py3-none-any.whl.metadata (18 kB)
# Collecting docstring-parser>=0.16 (from tyro<0.9.0->llamafactory[metrics])
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting shtab>=1.5.6 (from tyro<0.9.0->llamafactory[metrics])
#   Downloading shtab-1.8.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: colorama>=0.4.0 in E:\anaconda\envs\AIGC\Lib\site-packages (from tyro<0.9.0->llamafactory[metrics]) (0.4.6)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in E:\anaconda\envs\AIGC\Lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory[metrics]) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading frozenlist-1.8.0-cp311-cp311-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading multidict-6.7.1-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading propcache-0.4.1-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading yarl-1.23.0-cp311-cp311-win_amd64.whl.metadata (82 kB)
# Requirement already satisfied: contourpy>=1.0.1 in E:\anaconda\envs\AIGC\Lib\site-packages (from matplotlib>=3.7.0->llamafactory[metrics]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in E:\anaconda\envs\AIGC\Lib\site-packages (from matplotlib>=3.7.0->llamafactory[metrics]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in E:\anaconda\envs\AIGC\Lib\site-packages (from matplotlib>=3.7.0->llamafactory[metrics]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in E:\anaconda\envs\AIGC\Lib\site-packages (from matplotlib>=3.7.0->llamafactory[metrics]) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in E:\anaconda\envs\AIGC\Lib\site-packages (from matplotlib>=3.7.0->llamafactory[metrics]) (3.3.2)
# Requirement already satisfied: six>=1.5 in E:\anaconda\envs\AIGC\Lib\site-packages (from python-dateutil>=2.8.2->pandas->llamafactory[metrics]) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.32.2->datasets<=4.0.0,>=2.16.0->llamafactory[metrics])
#   Downloading charset_normalizer-3.4.5-cp311-cp311-win_amd64.whl.metadata (39 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.3.0->typer<1.0,>=0.12->gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in E:\anaconda\envs\AIGC\Lib\site-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio<=5.50.0,>=4.38.0->llamafactory[metrics]) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio<=5.50.0,>=4.38.0->llamafactory[metrics])
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting sympy>=1.13.3 (from torch>=2.4.0->llamafactory[metrics])
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=2.4.0->llamafactory[metrics])
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=2.4.0->llamafactory[metrics])
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting termcolor (from fire->llamafactory[metrics])
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: setuptools in E:\anaconda\envs\AIGC\Lib\site-packages (from modelscope->llamafactory[metrics]) (80.10.2)
# Collecting joblib (from nltk->llamafactory[metrics])
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->llamafactory[metrics])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Downloading llamafactory-0.9.4-py3-none-any.whl (398 kB)
# Downloading accelerate-1.11.0-py3-none-any.whl (375 kB)
# Downloading datasets-4.0.0-py3-none-any.whl (494 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading gradio-5.50.0-py3-none-any.whl (63.5 MB)
#    ---------------------------------------- 0.0/63.5 MB ? eta -:--:--
#    - -------------------------------------- 3.1/63.5 MB 15.3 MB/s eta 0:00:04
#    ---- ----------------------------------- 6.6/63.5 MB 16.1 MB/s eta 0:00:04
#    ------ --------------------------------- 10.0/63.5 MB 16.3 MB/s eta 0:00:04
#    -------- ------------------------------- 14.2/63.5 MB 17.1 MB/s eta 0:00:03
#    ----------- ---------------------------- 18.1/63.5 MB 17.3 MB/s eta 0:00:03
#    ------------- -------------------------- 21.2/63.5 MB 17.2 MB/s eta 0:00:03
#    --------------- ------------------------ 24.9/63.5 MB 17.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 28.6/63.5 MB 17.3 MB/s eta 0:00:03
#    ------------------- -------------------- 30.9/63.5 MB 16.5 MB/s eta 0:00:02
#    --------------------- ------------------ 34.1/63.5 MB 16.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 37.5/63.5 MB 16.4 MB/s eta 0:00:02
#    ------------------------- -------------- 41.2/63.5 MB 16.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 45.1/63.5 MB 16.6 MB/s eta 0:00:02
#    ------------------------------ --------- 49.0/63.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------- ------ 53.0/63.5 MB 16.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 56.9/63.5 MB 17.2 MB/s eta 0:00:01
#    ------------------------------------- -- 60.3/63.5 MB 17.1 MB/s eta 0:00:01
#    ---------------------------------------  63.4/63.5 MB 17.1 MB/s eta 0:00:01
#    ---------------------------------------- 63.5/63.5 MB 16.6 MB/s  0:00:03
# Downloading gradio_client-1.14.0-py3-none-any.whl (325 kB)
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
# Downloading fastapi-0.135.1-py3-none-any.whl (116 kB)
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp311-cp311-win_amd64.whl (15 kB)
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
# Downloading orjson-3.11.7-cp311-cp311-win_amd64.whl (124 kB)
# Downloading pandas-2.3.3-cp311-cp311-win_amd64.whl (11.3 MB)
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------- ----------------------------- 2.9/11.3 MB 12.9 MB/s eta 0:00:01
#    -------------------------- ------------- 7.6/11.3 MB 17.4 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.3 MB 18.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.3/11.3 MB 17.3 MB/s  0:00:00
# Downloading peft-0.17.1-py3-none-any.whl (504 kB)
# Downloading pillow-11.3.0-cp311-cp311-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    --------------------- ------------------ 3.7/7.0 MB 18.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 16.6 MB/s  0:00:00
# Downloading pydantic-2.12.3-py3-none-any.whl (462 kB)
# Downloading pydantic_core-2.41.4-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 14.1 MB/s  0:00:00
# Downloading pyyaml-6.0.3-cp311-cp311-win_amd64.whl (158 kB)
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.52.1-py3-none-any.whl (74 kB)
# Downloading tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Downloading torchdata-0.11.0-py3-none-any.whl (61 kB)
# Downloading transformers-4.57.1-py3-none-any.whl (12.0 MB)
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    ------------- -------------------------- 4.2/12.0 MB 21.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.7/12.0 MB 21.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 18.8 MB/s  0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ---------------------------------------- 0.0/566.4 kB ? eta -:--:--
#    ---------------------------------------- 566.4/566.4 kB 19.0 MB/s  0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------------------------- 2.7/2.7 MB 15.9 MB/s  0:00:00
# Downloading trl-0.24.0-py3-none-any.whl (423 kB)
# Downloading typer-0.24.1-py3-none-any.whl (56 kB)
# Downloading tyro-0.8.14-py3-none-any.whl (109 kB)
# Downloading websockets-15.0.1-cp311-cp311-win_amd64.whl (176 kB)
# Downloading aiohttp-3.13.3-cp311-cp311-win_amd64.whl (457 kB)
# Downloading multidict-6.7.1-cp311-cp311-win_amd64.whl (45 kB)
# Downloading yarl-1.23.0-cp311-cp311-win_amd64.whl (87 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading brotli-1.2.0-cp311-cp311-win_amd64.whl (369 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading frozenlist-1.8.0-cp311-cp311-win_amd64.whl (44 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading propcache-0.4.1-cp311-cp311-win_amd64.whl (41 kB)
# Downloading pyarrow-23.0.1-cp311-cp311-win_amd64.whl (27.5 MB)
#    ---------------------------------------- 0.0/27.5 MB ? eta -:--:--
#    ------ --------------------------------- 4.2/27.5 MB 20.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 8.1/27.5 MB 20.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 12.1/27.5 MB 19.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 15.5/27.5 MB 19.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 19.7/27.5 MB 19.1 MB/s eta 0:00:01
#    --------------------------------- ------ 23.3/27.5 MB 18.9 MB/s eta 0:00:01
#    ---------------------------------------  27.0/27.5 MB 18.6 MB/s eta 0:00:01
#    ---------------------------------------- 27.5/27.5 MB 17.1 MB/s  0:00:01
# Downloading python_multipart-0.0.22-py3-none-any.whl (24 kB)
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Downloading regex-2026.2.28-cp311-cp311-win_amd64.whl (277 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.5-cp311-cp311-win_amd64.whl (142 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Downloading rich-14.3.3-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading ruff-0.15.5-py3-none-win_amd64.whl (11.7 MB)
#    ---------------------------------------- 0.0/11.7 MB ? eta -:--:--
#    ----------- ---------------------------- 3.4/11.7 MB 16.8 MB/s eta 0:00:01
#    ------------------------ --------------- 7.1/11.7 MB 16.8 MB/s eta 0:00:01
#    ------------------------------------ --- 10.7/11.7 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.7/11.7 MB 16.2 MB/s  0:00:00
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading shtab-1.8.0-py3-none-any.whl (14 kB)
# Downloading torch-2.10.0-cp311-cp311-win_amd64.whl (113.7 MB)
#    ---------------------------------------- 0.0/113.7 MB ? eta -:--:--
#    - -------------------------------------- 3.7/113.7 MB 18.1 MB/s eta 0:00:07
#    -- ------------------------------------- 7.1/113.7 MB 18.2 MB/s eta 0:00:06
#    --- ------------------------------------ 11.3/113.7 MB 18.1 MB/s eta 0:00:06
#    ----- ---------------------------------- 15.2/113.7 MB 18.0 MB/s eta 0:00:06
#    ------ --------------------------------- 19.7/113.7 MB 18.5 MB/s eta 0:00:06
#    -------- ------------------------------- 23.6/113.7 MB 18.4 MB/s eta 0:00:05
#    --------- ------------------------------ 27.0/113.7 MB 18.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 31.5/113.7 MB 18.5 MB/s eta 0:00:05
#    ------------ --------------------------- 35.7/113.7 MB 18.7 MB/s eta 0:00:05
#    ------------- -------------------------- 39.6/113.7 MB 18.8 MB/s eta 0:00:04
#    -------------- ------------------------- 41.9/113.7 MB 18.1 MB/s eta 0:00:04
#    --------------- ------------------------ 45.4/113.7 MB 17.9 MB/s eta 0:00:04
#    ----------------- ---------------------- 49.5/113.7 MB 18.1 MB/s eta 0:00:04
#    ------------------ --------------------- 53.7/113.7 MB 18.1 MB/s eta 0:00:04
#    -------------------- ------------------- 57.9/113.7 MB 18.3 MB/s eta 0:00:04
#    --------------------- ------------------ 61.9/113.7 MB 18.3 MB/s eta 0:00:03
#    ---------------------- ----------------- 65.0/113.7 MB 18.2 MB/s eta 0:00:03
#    ------------------------ --------------- 68.7/113.7 MB 18.0 MB/s eta 0:00:03
#    ------------------------- -------------- 72.9/113.7 MB 18.2 MB/s eta 0:00:03
#    -------------------------- ------------- 76.3/113.7 MB 18.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 80.0/113.7 MB 18.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 83.9/113.7 MB 18.0 MB/s eta 0:00:02
#    ------------------------------- -------- 88.3/113.7 MB 18.1 MB/s eta 0:00:02
#    ------------------------------- -------- 91.0/113.7 MB 18.1 MB/s eta 0:00:02
#    -------------------------------- ------- 93.6/113.7 MB 17.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 96.7/113.7 MB 17.5 MB/s eta 0:00:01
#    ---------------------------------- ---- 100.4/113.7 MB 17.5 MB/s eta 0:00:01
#    ----------------------------------- --- 104.1/113.7 MB 17.5 MB/s eta 0:00:01
#    ------------------------------------- - 108.0/113.7 MB 17.5 MB/s eta 0:00:01
#    --------------------------------------  111.4/113.7 MB 17.5 MB/s eta 0:00:01
#    --------------------------------------  113.5/113.7 MB 17.4 MB/s eta 0:00:01
#    ---------------------------------------- 113.7/113.7 MB 16.7 MB/s  0:00:06
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 16.4 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    -------------------------- ------------- 4.2/6.3 MB 21.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 18.4 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 17.1 MB/s  0:00:00
# Downloading torchaudio-2.10.0-cp311-cp311-win_amd64.whl (474 kB)
# Downloading torchvision-0.25.0-cp311-cp311-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -------------------------------------- - 3.9/4.0 MB 19.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 18.6 MB/s  0:00:00
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Downloading uvicorn-0.41.0-py3-none-any.whl (68 kB)
# Downloading av-16.1.0-cp311-cp311-win_amd64.whl (31.8 MB)
#    ---------------------------------------- 0.0/31.8 MB ? eta -:--:--
#    ---- ----------------------------------- 3.7/31.8 MB 18.1 MB/s eta 0:00:02
#    --------- ------------------------------ 7.3/31.8 MB 18.1 MB/s eta 0:00:02
#    -------------- ------------------------- 11.8/31.8 MB 18.5 MB/s eta 0:00:02
#    ------------------- -------------------- 15.2/31.8 MB 18.4 MB/s eta 0:00:01
#    ------------------------ --------------- 19.7/31.8 MB 18.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 23.6/31.8 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 27.3/31.8 MB 18.4 MB/s eta 0:00:01
#    ---------------------------------------  31.2/31.8 MB 18.5 MB/s eta 0:00:01
#    ---------------------------------------- 31.8/31.8 MB 17.5 MB/s  0:00:01
# Downloading einops-0.8.2-py3-none-any.whl (65 kB)
# Downloading ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Downloading filelock-3.25.0-py3-none-any.whl (26 kB)
# Downloading fire-0.7.1-py3-none-any.whl (115 kB)
# Downloading hf_transfer-0.1.9-cp38-abi3-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 19.1 MB/s  0:00:00
# Downloading modelscope-1.34.0-py3-none-any.whl (6.1 MB)
#    ---------------------------------------- 0.0/6.1 MB ? eta -:--:--
#    ------------------------ --------------- 3.7/6.1 MB 19.8 MB/s eta 0:00:01
#    ---------------------------------------  6.0/6.1 MB 14.8 MB/s eta 0:00:01
#    ---------------------------------------- 6.1/6.1 MB 14.3 MB/s  0:00:00
# Downloading nltk-3.9.3-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 16.2 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading rouge_chinese-1.0.3-py3-none-any.whl (21 kB)
# Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---- ----------------------------------- 3.7/36.6 MB 19.8 MB/s eta 0:00:02
#    -------- ------------------------------- 8.1/36.6 MB 19.4 MB/s eta 0:00:02
#    ------------- -------------------------- 12.3/36.6 MB 19.3 MB/s eta 0:00:02
#    ------------------ --------------------- 16.5/36.6 MB 19.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 20.2/36.6 MB 18.8 MB/s eta 0:00:01
#    -------------------------- ------------- 24.1/36.6 MB 18.9 MB/s eta 0:00:01
#    ------------------------------ --------- 28.0/36.6 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.0/36.6 MB 18.8 MB/s eta 0:00:01
#    -------------------------------------- - 35.7/36.6 MB 18.6 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 18.0 MB/s  0:00:02
# Downloading sentencepiece-0.2.1-cp311-cp311-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 16.9 MB/s  0:00:00
# Downloading sse_starlette-3.3.2-py3-none-any.whl (14 kB)
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading tiktoken-0.12.0-cp311-cp311-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.4 kB ? eta -:--:--
#    ---------------------------------------- 879.4/879.4 kB 19.9 MB/s  0:00:00
# Downloading xxhash-3.6.0-cp311-cp311-win_amd64.whl (31 kB)
# Building wheels for collected packages: jieba, antlr4-python3-runtime
#   Building wheel for jieba (pyproject.toml): started
#   Building wheel for jieba (pyproject.toml): finished with status 'done'
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314527 sha256=d0bfc2ada138c92402178c739292947e6134a429b4dd8609611571506d9f3ea0
#   Stored in directory: c:\users\86135\appdata\local\pip\cache\wheels\ac\60\cf\538a1f183409caf1fc136b5d2c2dee329001ef6da2c5084bef
#   Building wheel for antlr4-python3-runtime (pyproject.toml): started
#   Building wheel for antlr4-python3-runtime (pyproject.toml): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144615 sha256=a3ebb3a1d8fde9cd79c732a12081002f506789277a00d4cb43ea84fd110e1286
#   Stored in directory: c:\users\86135\appdata\local\pip\cache\wheels\1a\97\32\461f837398029ad76911109f07047fde1d7b661a147c7c56d1
# Successfully built jieba antlr4-python3-runtime
# Installing collected packages: pytz, pydub, mpmath, jieba, brotli, antlr4-python3-runtime, xxhash, websockets, urllib3, tzdata, typing-inspection, tqdm, tomlkit, termcolor, sympy, shtab, shellingham, sentencepiece, semantic-version, scipy, safetensors, ruff, rouge-chinese, regex, pyyaml, python-multipart, pydantic-core, pyarrow, propcache, pillow, orjson, networkx, multidict, mdurl, markupsafe, joblib, idna, hf-transfer, h11, groovy, fsspec, frozenlist, filelock, ffmpy, einops, docstring-parser, dill, click, charset_normalizer, certifi, av, annotated-types, annotated-doc, aiohappyeyeballs, aiofiles, yarl, uvicorn, requests, pydantic, pandas, omegaconf, nltk, multiprocess, markdown-it-py, jinja2, httpcore, fire, anyio, aiosignal, torch, tiktoken, starlette, rich, modelscope, huggingface_hub, httpx, aiohttp, tyro, typer, torchvision, torchdata, torchaudio, tokenizers, sse-starlette, safehttpx, gradio-client, fastapi, accelerate, transformers, gradio, datasets, trl, peft, llamafactory
#
#    ----------------------------------------  0/94 [pytz]
#    ----------------------------------------  0/94 [pytz]
#     ---------------------------------------  2/94 [mpmath]
#     ---------------------------------------  2/94 [mpmath]
#     ---------------------------------------  2/94 [mpmath]
#     ---------------------------------------  2/94 [mpmath]
#    - --------------------------------------  3/94 [jieba]
#    - --------------------------------------  3/94 [jieba]
#    - --------------------------------------  3/94 [jieba]
#    - --------------------------------------  3/94 [jieba]
#    - --------------------------------------  3/94 [jieba]
#    -- -------------------------------------  5/94 [antlr4-python3-runtime]
#    -- -------------------------------------  7/94 [websockets]
#    -- -------------------------------------  7/94 [websockets]
#    --- ------------------------------------  8/94 [urllib3]
#    --- ------------------------------------  9/94 [tzdata]
#    --- ------------------------------------  9/94 [tzdata]
#    ---- ----------------------------------- 11/94 [tqdm]
#    ----- ---------------------------------- 12/94 [tomlkit]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    ----- ---------------------------------- 14/94 [sympy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 19/94 [scipy]
#    -------- ------------------------------- 21/94 [ruff]
#    --------- ------------------------------ 22/94 [rouge-chinese]
#    ---------- ----------------------------- 24/94 [pyyaml]
#    ---------- ----------------------------- 25/94 [python-multipart]
#    ----------- ---------------------------- 27/94 [pyarrow]
#    ----------- ---------------------------- 27/94 [pyarrow]
#    ----------- ---------------------------- 27/94 [pyarrow]
#    ----------- ---------------------------- 27/94 [pyarrow]
#    ----------- ---------------------------- 27/94 [pyarrow]
#    ----------- ---------------------------- 27/94 [pyarrow]
#    ----------- ---------------------------- 27/94 [pyarrow]
#    ----------- ---------------------------- 27/94 [pyarrow]
#    ----------- ---------------------------- 27/94 [pyarrow]
#    ----------- ---------------------------- 27/94 [pyarrow]
#    ----------- ---------------------------- 27/94 [pyarrow]
#    ----------- ---------------------------- 27/94 [pyarrow]
#    ----------- ---------------------------- 27/94 [pyarrow]
#    ----------- ---------------------------- 28/94 [propcache]
#   Attempting uninstall: pillow
#    ----------- ---------------------------- 28/94 [propcache]
#     Found existing installation: pillow 12.1.1
#    ----------- ---------------------------- 28/94 [propcache]
#     Uninstalling pillow-12.1.1:
#    ----------- ---------------------------- 28/94 [propcache]
#       Successfully uninstalled pillow-12.1.1
#    ----------- ---------------------------- 28/94 [propcache]
#    ------------ --------------------------- 29/94 [pillow]
#    ------------ --------------------------- 29/94 [pillow]
#    ------------ --------------------------- 29/94 [pillow]
#    ------------ --------------------------- 29/94 [pillow]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    ------------- -------------------------- 31/94 [networkx]
#    -------------- ------------------------- 34/94 [markupsafe]
#    -------------- ------------------------- 35/94 [joblib]
#    -------------- ------------------------- 35/94 [joblib]
#    --------------- ------------------------ 36/94 [idna]
#    ----------------- ---------------------- 40/94 [fsspec]
#    ----------------- ---------------------- 40/94 [fsspec]
#    ----------------- ---------------------- 40/94 [fsspec]
#    ------------------ --------------------- 44/94 [einops]
#    ------------------- -------------------- 45/94 [docstring-parser]
#    ------------------- -------------------- 46/94 [dill]
#    -------------------- ------------------- 48/94 [charset_normalizer]
#    --------------------- ------------------ 50/94 [av]
#    --------------------- ------------------ 50/94 [av]
#    --------------------- ------------------ 50/94 [av]
#    --------------------- ------------------ 50/94 [av]
#    --------------------- ------------------ 50/94 [av]
#    --------------------- ------------------ 51/94 [annotated-types]
#    ---------------------- ----------------- 54/94 [aiofiles]
#    ----------------------- ---------------- 56/94 [uvicorn]
#    ------------------------ --------------- 57/94 [requests]
#    ------------------------ --------------- 58/94 [pydantic]
#    ------------------------ --------------- 58/94 [pydantic]
#    ------------------------ --------------- 58/94 [pydantic]
#    ------------------------ --------------- 58/94 [pydantic]
#    ------------------------- -------------- 59/94 [pandas]
#    ------------------------- -------------- 59/94 [pandas]
#    ------------------------- -------------- 59/94 [pandas]
#    ------------------------- -------------- 59/94 [pandas]
#    ------------------------- -------------- 59/94 [pandas]
#    ------------------------- -------------- 59/94 [pandas]
#    ------------------------- -------------- 59/94 [pandas]
# ...
#    ----------------------------- ---------- 69/94 [torch]
#    ----------------------------- ---------- 69/94 [torch]
#    ----------------------------- ---------- 69/94 [torch]
#    ----------------------------- ---------- 69/94 [torch]
#    ----------------------------- ---------- 69/94 [torch]
#    ------------------------------ --------- 71/94 [starlette]
#    ------------------------------ --------- 72/94 [rich]
#    ------------------------------ --------- 72/94 [rich]
#    ------------------------------ --------- 72/94 [rich]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 73/94 [modelscope]
#    ------------------------------- -------- 74/94 [huggingface_hub]
#    ------------------------------- -------- 74/94 [huggingface_hub]
#    ------------------------------- -------- 74/94 [huggingface_hub]
#    ------------------------------- -------- 74/94 [huggingface_hub]
#    ------------------------------- -------- 74/94 [huggingface_hub]
#    ------------------------------- -------- 75/94 [httpx]
#    -------------------------------- ------- 76/94 [aiohttp]
#    -------------------------------- ------- 76/94 [aiohttp]
#    -------------------------------- ------- 76/94 [aiohttp]
#    -------------------------------- ------- 77/94 [tyro]
#    --------------------------------- ------ 79/94 [torchvision]
#    --------------------------------- ------ 79/94 [torchvision]
#    --------------------------------- ------ 79/94 [torchvision]
#    --------------------------------- ------ 79/94 [torchvision]
#    --------------------------------- ------ 79/94 [torchvision]
#    --------------------------------- ------ 79/94 [torchvision]
#    ---------------------------------- ----- 80/94 [torchdata]
#    ---------------------------------- ----- 81/94 [torchaudio]
#    ---------------------------------- ----- 81/94 [torchaudio]
#    ---------------------------------- ----- 82/94 [tokenizers]
#    ------------------------------------ --- 85/94 [gradio-client]
#    ------------------------------------ --- 86/94 [fastapi]
#    ------------------------------------- -- 87/94 [accelerate]
#    ------------------------------------- -- 87/94 [accelerate]
#    ------------------------------------- -- 87/94 [accelerate]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 88/94 [transformers]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    ------------------------------------- -- 89/94 [gradio]
#    -------------------------------------- - 90/94 [datasets]
#    -------------------------------------- - 90/94 [datasets]
#    -------------------------------------- - 90/94 [datasets]
#    -------------------------------------- - 90/94 [datasets]
#    -------------------------------------- - 91/94 [trl]
#    -------------------------------------- - 91/94 [trl]
#    ---------------------------------------  92/94 [peft]
#    ---------------------------------------  92/94 [peft]
#    ---------------------------------------  92/94 [peft]
#    ---------------------------------------  92/94 [peft]
#    ---------------------------------------  93/94 [llamafactory]
#    ---------------------------------------  93/94 [llamafactory]
#    ---------------------------------------  93/94 [llamafactory]
#    ---------------------------------------  93/94 [llamafactory]
#    ---------------------------------------- 94/94 [llamafactory]
#
# Successfully installed accelerate-1.11.0 aiofiles-24.1.0 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 annotated-doc-0.0.4 annotated-types-0.7.0 antlr4-python3-runtime-4.9.3 anyio-4.12.1 av-16.1.0 brotli-1.2.0 certifi-2026.2.25 charset_normalizer-3.4.5 click-8.3.1 datasets-4.0.0 dill-0.3.8 docstring-parser-0.17.0 einops-0.8.2 fastapi-0.135.1 ffmpy-1.0.0 filelock-3.25.0 fire-0.7.1 frozenlist-1.8.0 fsspec-2025.3.0 gradio-5.50.0 gradio-client-1.14.0 groovy-0.1.2 h11-0.16.0 hf-transfer-0.1.9 httpcore-1.0.9 httpx-0.28.1 huggingface_hub-0.36.2 idna-3.11 jieba-0.42.1 jinja2-3.1.6 joblib-1.5.3 llamafactory-0.9.4 markdown-it-py-4.0.0 markupsafe-3.0.3 mdurl-0.1.2 modelscope-1.34.0 mpmath-1.3.0 multidict-6.7.1 multiprocess-0.70.16 networkx-3.6.1 nltk-3.9.3 omegaconf-2.3.0 orjson-3.11.7 pandas-2.3.3 peft-0.17.1 pillow-11.3.0 propcache-0.4.1 pyarrow-23.0.1 pydantic-2.12.3 pydantic-core-2.41.4 pydub-0.25.1 python-multipart-0.0.22 pytz-2026.1.post1 pyyaml-6.0.3 regex-2026.2.28 requests-2.32.5 rich-14.3.3 rouge-chinese-1.0.3 ruff-0.15.5 safehttpx-0.1.7 safetensors-0.7.0 scipy-1.17.1 semantic-version-2.10.0 sentencepiece-0.2.1 shellingham-1.5.4 shtab-1.8.0 sse-starlette-3.3.2 starlette-0.52.1 sympy-1.14.0 termcolor-3.3.0 tiktoken-0.12.0 tokenizers-0.22.2 tomlkit-0.13.3 torch-2.10.0 torchaudio-2.10.0 torchdata-0.11.0 torchvision-0.25.0 tqdm-4.67.3 transformers-4.57.1 trl-0.24.0 typer-0.24.1 typing-inspection-0.4.2 tyro-0.8.14 tzdata-2025.3 urllib3-2.6.3 uvicorn-0.41.0 websockets-15.0.1 xxhash-3.6.0 yarl-1.23.0

# %%
## 检测是否安装成功
# !llamafactory-cli version

# %% [markdown]
# ## 2. 下载 Qwen 模型 (使用阿里内网极速下载)

# %%
import os
from modelscope import snapshot_download

# 1. 指定模型：Qwen2.5-7B-Instruct
# 这是通义千问 2.5 版本的 7B 指令微调模型
# 特点：中文能力极强，指令遵循度高，非常适合作为微调的基座（不易翻车）
model_id = 'Qwen/Qwen2.5-7B-Instruct'

print(f"🚀 正在从 ModelScope 下载 {model_id}...")
print("阿里云内网速度极快 (50MB/s+)，请稍等片刻...")

# cache_dir 指定下载到当前目录下的 models 文件夹，方便好找
# revision='master' 确保下载的是主分支最新版本
model_dir = snapshot_download(model_id, cache_dir='./models', revision='master')

print(f"\n✅ 模型下载完成！路径位于: {model_dir}")

# %% [markdown]
# ## 3. 使用代码加载“原版”模型 + 连续对话

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

# 1. 加载模型
# 注意：这里路径填刚才下载好的路径
model_path = "./models/Qwen/Qwen2___5-7B-Instruct"

print("🚀 正在加载 Qwen 原版模型...")
tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    model_path, 
    torch_dtype=torch.float16, 
    device_map="auto", 
    trust_remote_code=True
)

print("✅ 加载成功！进入对话模式 (输入 'exit' 退出)")
print("-" * 30)

# 2. 连续对话循环
# DeepSeek 有自己的对话模板，我们用官方推荐的 apply_chat_template
messages = [] # 用于存储历史记录

while True:
    query = input("\n👩‍🏫 用户: ")
    if query.strip() == "exit":
        break
    
    # 将用户问题加入历史
    messages.append({"role": "user", "content": query})
    
    # 构建 Prompt
    #inputs = tokenizer.apply_chat_template(messages, return_tensors="pt").to(model.device)
    inputs = tokenizer.apply_chat_template(
                        messages, 
                        return_tensors="pt", 
                        add_generation_prompt=True
                        ).to(model.device)
    
    # 生成回答
    outputs = model.generate(
        inputs, 
        max_new_tokens=512, 
        do_sample=True, 
        top_k=50, 
        top_p=0.95,
        temperature=0.7,
        pad_token_id=tokenizer.eos_token_id
    )
    
    # 解码
    response = tokenizer.decode(outputs[0][len(inputs[0]):], skip_special_tokens=True)
    print(f"🤖 Qwen: {response}")
    
    # 将 AI 回答加入历史，实现连续对话
    messages.append({"role": "assistant", "content": response})

# %% [markdown]
# # *.可能存在的数据后处理

# %%
## 可能存在的收据后处理 

import json
import re

# 1. 把你的文件名填在这里
input_file = "xiyouji4_dataset.jsonl"  # 你的原始文件
output_file = "cleaned_data.jsonl" # 清洗后的文件

cleaned_count = 0

with open(output_file, 'w', encoding='utf-8') as f_out:
    with open(input_file, 'r', encoding='utf-8') as f_in:
        for line in f_in:
            try:
                # 解析最外层
                data = json.loads(line)
                
                # 1. 捞出“问题” (在外层的 input 字段里)
                # 注意：有时候EasyDataSet会把问题放在input，有时候在instruction，视配置而定
                # 这里根据你的样本，问题在 input 里
                question = data.get('input', '')
                
                # 2. 捞出“思考过程”后面的 JSON
                raw_content = data.get('output', '')
                
                # 去掉 <think>...</think> 及其里面的废话
                # 使用非贪婪匹配，把思考部分删掉
                content_no_think = re.sub(r'<think>.*?</think>', '', raw_content, flags=re.DOTALL)
                
                # 3. 提取内层 JSON
                # 寻找第一个 { 和 最后一个 } 之间的内容
                json_match = re.search(r'\{.*\}', content_no_think, re.DOTALL)
                
                if json_match:
                    inner_json_str = json_match.group(0)
                    inner_data = json.loads(inner_json_str)
                    
                    # 4. 组装成完美的 Alpaca 格式
                    new_entry = {
                        "instruction": question,               # 问题放这里
                        "input": inner_data.get('input', ''),  # 原文背景放这里
                        "output": inner_data.get('output', '') # 答案放这里
                    }
                    
                    # 写入新文件
                    f_out.write(json.dumps(new_entry, ensure_ascii=False) + '\n')
                    cleaned_count += 1
                    
            except Exception as e:
                print(f"跳过一行坏数据: {e}")
                continue

print(f"大功告成！成功清洗并拯救了 {cleaned_count} 条数据！")
print(f"请使用新文件: {output_file} 进行微调。")

# %% [markdown]
# ## 4. 放置你的数据集文件
#
#
# 1. 将数据集```json```文件放至``` LLaMA-Factory/data/``` 文件夹下
# 2. 在 ```LLaMA-Factory/data/dataset_info.json``` 文件的最后加入你的数据集的信息，类似
# ```
# ...
# },
# "aojiao_daye": {
#     "file_name": "aojiao_daye.jsonl",
#     "formatting": "sharegpt",
#     "columns": {
#       "messages": "messages"
#     },
#     "tags": {
#       "role_tag": "role",
#       "content_tag": "content",
#       "user_tag": "user",
#       "assistant_tag": "assistant",
#       "system_tag": "system"
#     }
#   }
# ```
# 一定要注意要给上一行之前加上逗号，否则JSON文件会报错。

# %% [markdown]
# ## 5. 启动 LLaMA-Factory WebUI 进行微调

# %%
# !export USE_MODELSCOPE_HUB=1 && \
llamafactory-cli webui

# %%
# !ps

# %% [markdown]
# ## *6. 加载微调后的模型和LoRA插件

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel

# 1. 路径设置
# 原版模型路径 (刚才你填的那个绝对路径)
base_model_path = "./models/Qwen/Qwen2___5-7B-Instruct"

# 微调后的 LoRA 路径 (就在 LLaMA-Factory 目录下)
# 注意：请把下面的路径换成你日志里显示的那个具体路径
lora_path = "./LLaMA-Factory/saves/DeepSeek-R1-1.5B-Distill/lora/train_2025-11-23-19-40-50"

print("🚀 正在加载原版模型...")
tokenizer = AutoTokenizer.from_pretrained(base_model_path, trust_remote_code=True)
base_model = AutoModelForCausalLM.from_pretrained(
    base_model_path, 
    torch_dtype=torch.float16, 
    device_map="auto", 
    trust_remote_code=True
)

print("🔌 正在挂载微调 LoRA 适配器...")
# 关键步骤：把 LoRA "挂" 到原模型上
model = PeftModel.from_pretrained(base_model, lora_path)

print("✅ 加载完成！开始测试...")

# 2. 测试对话
messages = [
    {"role": "user", "content": "你是谁？"}
]

inputs = tokenizer.apply_chat_template(
    messages, 
    return_tensors="pt", 
    add_generation_prompt=True
).to(model.device)

outputs = model.generate(
    inputs, 
    max_new_tokens=200, 
    do_sample=True, 
    temperature=0.7
)

response = tokenizer.decode(outputs[0][len(inputs[0]):], skip_special_tokens=True)
print(f"\n🤖 回答: {response}")
